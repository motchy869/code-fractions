# %%
using Plots

# %%
Plots.theme(:dark)

# %%
include("include.jl")
# Out:
# Main.ExpSmoothingFilter

# %%
filter = ExpSmoothingFilter.FilterState{Float64}(0.1)
# Out:
# Main.ExpSmoothingFilter.FilterState{Float64}(0.1, 0.9, 0.0, true)

# %%
vec_x = [ExpSmoothingFilter.step(filter, Float64((m -> (m <= 50 ? 0 : 1))(n))) for n in 1:100];

# %%
plot(vec_x)
